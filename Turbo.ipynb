# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Book1.xlsx', index_col= 0)
dff = pd.read_excel('Book1.xlsx', index_col= 0)
dff.reset_index

df.head()
# Out:
#                          Time  58PDI1202.PV  58TI3246.PV  58PIC3226A.PV  \
# Date
# 2018-08-16 00:00:00  00:00:00      0.485438    13.704390     759.735596
# 2018-08-16 01:00:00  01:00:00      0.486443    14.682747     758.939575
# 2018-08-16 02:00:00  02:00:00      0.496587    14.022818     761.087402
# 2018-08-16 03:00:00  03:00:00      0.532740    13.443664     759.993347
# 2018-08-16 04:00:00  04:00:00      0.584378    12.676052     760.262573
#
#                      58HIC3225.MV  58ZI3225.PV  58PI3239.PV  58TI3230.PV  \
# Date
# 2018-08-16 00:00:00     82.490387    82.814613   168.270096   127.014091
# 2018-08-16 01:00:00     84.825310    85.061035   168.685211   128.635193
# 2018-08-16 02:00:00     84.914108    85.217781   169.251389   128.156845
# 2018-08-16 03:00:00     83.618591    83.950287   168.628265   127.136993
# 2018-08-16 04:00:00     82.454002    82.755478   168.529510   126.012871
#
# ...

# %%
df.shape
df  = df.drop(['Time'],axis=1)

# %%
X = df.values
X.shape
# Out:
# (192, 109)

# %%
import sklearn

# %%
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
print(X)
print(X_scaled)
# Out:
# [[4.85437572e-01 1.37043896e+01 7.59735596e+02 ... 3.08491455e+02
#   1.38617749e+03 9.60284958e+01]
#  [4.86443281e-01 1.46827469e+01 7.58939575e+02 ... 3.07626678e+02
#   1.38332385e+03 9.60397644e+01]
#  [4.96586889e-01 1.40228176e+01 7.61087402e+02 ... 3.07028870e+02
#   1.38136401e+03 9.61131592e+01]
#  ...
#  [4.64839876e-01 1.16572762e+01 7.60728271e+02 ... 3.12714050e+02
#   1.39520435e+03 9.51234665e+01]
#  [4.67144787e-01 1.11328239e+01 7.60498901e+02 ... 3.14445190e+02
#   1.39940503e+03 9.48388367e+01]
#  [4.68126863e-01 1.09118242e+01 7.60193115e+02 ... 3.15065063e+02
#   1.40137793e+03 9.46772766e+01]]
# [[ 2.37419655e-01 -6.74275302e-01 -7.96194910e-03 ... -7.86444753e-02
#    6.21888656e-02  4.54951599e-01]
#  [ 2.51112166e-01 -3.96484791e-01 -4.79882448e-01 ... -3.10692539e-01
#   -2.53707083e-01  4.70581846e-01]
#  [ 3.89215180e-01 -5.83862233e-01  7.93456185e-01 ... -4.71104351e-01
#   -4.70660116e-01  5.72384819e-01]
#  ...
# ...

# %%
    from sklearn.decomposition import PCA
    
    pca_109 = PCA(n_components= 30, random_state=2020)

    pca_109.fit(X_scaled)

    X_pca_109 = pca_109.transform(X_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\My Drive\PCA TEST\Turbo.ipynb Cell 7' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/PCA%20TEST/Turbo.ipynb#ch0000006?line=0'>1</a> from sklearn.decomposition import PCA
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/PCA%20TEST/Turbo.ipynb#ch0000006?line=2'>3</a> pca_109 = PCA(n_components= 30, random_state=2020)
# ----> <a href='vscode-notebook-cell:/g%3A/My%20Drive/PCA%20TEST/Turbo.ipynb#ch0000006?line=4'>5</a> pca_109.fit(X_scaled)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/PCA%20TEST/Turbo.ipynb#ch0000006?line=6'>7</a> X_pca_109 = pca_109.transform(X_scaled)
#
# NameError: name 'X_scaled' is not defined

# %%
varr = pca_109.explained_variance_ratio_*100
varr
# Out:
# array([51.43695378, 16.67064267,  6.63492639,  5.95885332,  3.86918212,
#         2.69278842,  2.04733095,  1.47414857,  1.26961273,  1.04905313,
#         0.88200363,  0.6998019 ,  0.6480305 ,  0.59962665,  0.4696704 ,
#         0.44199675,  0.40046893,  0.39304846,  0.29259919,  0.25184265,
#         0.21609891,  0.19394974,  0.16394706,  0.14618967,  0.11777651,
#         0.09932287,  0.09122689,  0.08808138,  0.07087751,  0.0686689 ])

# %%
np.cumsum(varr)
# Out:
# array([ 51.43695378,  68.10759645,  74.74252283,  80.70137616,
#         84.57055828,  87.2633467 ,  89.31067765,  90.78482622,
#         92.05443895,  93.10349208,  93.98549571,  94.68529761,
#         95.33332811,  95.93295476,  96.40262516,  96.84462191,
#         97.24509084,  97.63813929,  97.93073848,  98.18258114,
#         98.39868004,  98.59262978,  98.75657684,  98.90276651,
#         99.02054302,  99.11986589,  99.21109277,  99.29917415,
#         99.37005167,  99.43872057,  99.50129433,  99.55762167,
#         99.60895345,  99.6512601 ,  99.6882011 ,  99.72129611,
#         99.75376937,  99.78032247,  99.80363425,  99.82255579,
#         99.84048807,  99.85621248,  99.86950078,  99.88180589,
#         99.89305534,  99.90383745,  99.91322119,  99.92173276,
#         99.92949882,  99.93643058,  99.94319205,  99.94949197,
#         99.95466315,  99.95918026,  99.96324394,  99.96694566,
#         99.97041131,  99.97355238,  99.97637995,  99.9789603 ,
# ...

# %%
plt.plot(varr)

# %%
pca_2 = PCA(n_components=10,random_state=1000)
pca_2.fit(X_scaled)
X_pca_2 = pca_2.transform(X_scaled)

# %%
varr
# Out:
# array([51.43695378, 16.67064267,  6.63492639])

# %%
with plt.style.context('dark_background'):
    plt.figure(figsize=(15,10))

    plt.bar(range(25), varr/100, alpha=0.5, align='center',
            label='individual explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()

# %%
correlation = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>

# %%
dff = df.drop('Time',axis = 1)
dff
# Out:
#                      58PDI1202.PV  58TI3246.PV  58PIC3226A.PV  58HIC3225.MV  \
# Date
# 2018-08-16 00:00:00      0.485438    13.704390     759.735596     82.490387
# 2018-08-16 01:00:00      0.486443    14.682747     758.939575     84.825310
# 2018-08-16 02:00:00      0.496587    14.022818     761.087402     84.914108
# 2018-08-16 03:00:00      0.532740    13.443664     759.993347     83.618591
# 2018-08-16 04:00:00      0.584378    12.676052     760.262573     82.454002
# ...                           ...          ...            ...           ...
# 2018-08-24 01:00:00      0.473993    11.786310     760.520081     77.178696
# 2018-08-24 02:00:00      0.467463    11.900259     760.181030     77.017929
# 2018-08-24 03:00:00      0.464840    11.657276     760.728271     76.772148
# 2018-08-24 04:00:00      0.467145    11.132824     760.498901     75.521309
# 2018-08-24 05:00:00      0.468127    10.911824     760.193115     75.030769
#
# ...

# %%
dff.shape
# Out:
# (192, 109)

# %%
from sklearn import preprocessing
scaled_data = preprocessing.scale(dff.T)
pca = PCA()
pca.fit(scaled_data)
pca_data = pca.transform(scaled_data)
pca_data = pca.transform(pca_data)
pca_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# g:\My Drive\PCA TEST\Turbo.ipynb Cell 17' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/PCA%20TEST/Turbo.ipynb#ch0000019?line=3'>4</a> pca.fit(scaled_data)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/PCA%20TEST/Turbo.ipynb#ch0000019?line=4'>5</a> pca_data = pca.transform(scaled_data)
# ----> <a href='vscode-notebook-cell:/g%3A/My%20Drive/PCA%20TEST/Turbo.ipynb#ch0000019?line=5'>6</a> pca_data = pca.transform(pca_data)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/PCA%20TEST/Turbo.ipynb#ch0000019?line=6'>7</a> pca_data
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\decomposition\_base.py:120, in _BasePCA.transform(self, X)
# ...

# %%
per_ver = pca.explained_variance_ratio_
per_ver
# Out:
# array([9.99993981e-01, 4.66482465e-06, 7.05449350e-07, 4.51296990e-07,
#        1.70972174e-07, 1.58004188e-08, 5.05764805e-09, 3.16183002e-09,
#        6.64164980e-10, 6.32115475e-10, 3.41601826e-10, 2.42037631e-10,
#        2.12082467e-10, 1.45023792e-10, 6.96003787e-11, 6.47759425e-11,
#        5.19878759e-11, 3.57192818e-11, 2.85533628e-11, 2.42251236e-11,
#        2.04573215e-11, 1.61953036e-11, 1.00224959e-11, 9.23453482e-12,
#        7.87988959e-12, 5.64095337e-12, 5.03208698e-12, 4.48055221e-12,
#        3.37242361e-12, 2.94854901e-12, 2.30970504e-12, 2.11487795e-12,
#        1.82714626e-12, 1.59511543e-12, 1.28178409e-12, 1.23805526e-12,
#        1.08699740e-12, 1.01015869e-12, 8.64859000e-13, 7.80338607e-13,
#        6.33473831e-13, 5.60631259e-13, 4.55410262e-13, 4.19614460e-13,
#        3.76350751e-13, 3.53070316e-13, 2.72375527e-13, 2.32412790e-13,
#        2.19764554e-13, 1.87526407e-13, 1.65343075e-13, 1.57388805e-13,
# ...

# %%
plt.figure(figsize =(10,10))
labels = ['PC' + str(x) for x in range(1,len(varr)+1)]
plt.bar(x = range(1,len(varr)+1),height = varr, tick_label =labels)
# Out:
# <BarContainer object of 30 artists>

# %%
pca_df = pd.DataFrame(X_pca_109)

# %%
pca_df
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.831807 -1.409666 -0.649151 -0.252109  5.372880  4.929339 -0.088731
# 1     1.308848 -1.202074 -1.124630  0.196345  3.978600 -1.437772 -1.462806
# 2     0.695631 -1.762999 -3.789233 -1.293818  2.741234 -0.776474 -1.141128
# 3    -0.268076 -1.398477 -2.022174 -0.750626  4.234487 -1.883741 -0.907444
# 4    -1.737866 -1.120452 -0.998125 -2.363713  4.847873 -2.832356 -0.505972
# ..         ...       ...       ...       ...       ...       ...       ...
# 187  -5.321524 -5.488164 -2.428397  3.263497 -1.638132 -0.054438 -0.684398
# 188  -6.396318 -4.704834 -2.129935  3.559354 -1.164098 -0.569751 -0.147895
# 189  -8.426948 -4.706928 -1.589742  1.962438 -0.587066 -1.552617  1.061833
# 190 -10.018027 -4.787396  0.061166  0.840836 -0.717039 -1.925476  0.719855
# 191 -10.849555 -4.727860  1.340361  0.632556 -0.432947 -1.710341  0.886994
#
# ...

# %%
plt.scatter(pca_df[0], pca_df[1])
plt.xlabel('PC1-{0}%'.format(varr[0]))
plt.ylabel('PC2-{0}%'.format(varr[1]))
# Out:
# Text(0, 0.5, 'PC2-16.67064266547295%')

# %%
loading_scores = pd.Series(pca_109.components_[0])
sorted_loading_scores = loading_scores.abs().sort_values(ascending=False)
sorted_loading_scores
# Out:
# 67     0.132622
# 105    0.132567
# 92     0.132557
# 62     0.132443
# 57     0.132089
#          ...
# 39     0.006213
# 91     0.005560
# 82     0.003781
# 21     0.003020
# 48     0.000000
# Length: 109, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\My Drive\PCA TEST\Turbo.ipynb Cell 24' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/g%3A/My%20Drive/PCA%20TEST/Turbo.ipynb#ch0000023?line=0'>1</a> dff
#
# NameError: name 'dff' is not defined
